# %%
import sqlite3
import pandas as pd

# Path to your gold database
db_path = "data/silver/github_events.db"

# Create a connection and run a query into a DataFrame
conn = sqlite3.connect(db_path)
query = "SELECT * from events limit 10;"  # Change table and limit as desired

df = pd.read_sql_query(query, conn)
conn.close()

# Print the table nicely
display(df)
# Out:
#             id              type           actor   actor_id  \
# 0  49593660354        WatchEvent     suprahumano  197304299
# 1  49593660325  PullRequestEvent  reginaldogomes    3587008
# 2  49593660299  PullRequestEvent   renovate[bot]   29139614
# 3  49593660291        WatchEvent         lgf5090  170180789
# 4  49593660259        WatchEvent             YCF      65446
# 5  49593660162  PullRequestEvent   renovate[bot]   29139614
# 6  49593660033        WatchEvent     suprahumano  197304299
# 7  49593660032  PullRequestEvent       Samukaa05  183144160
# 8  49593660031        WatchEvent    studiomohawk      28534
# 9  49593659991  PullRequestEvent   renovate[bot]   29139614
#
#                                      repo    repo_id  public  \
# 0              coleam00/local-ai-packaged  933862859       1
# 1  reginaldogomes/nextjs-developer-resume  861976246       1
# 2                        svglol/predictor  652529438       1
# 3                      LibreSpark/LibreTV  961357433       1
# 4              supsupsuperstar/fc2_gather  328142338       1
# 5                visualon/docker-renovate  570445968       1
# 6              coleam00/local-ai-packaged  933862859       1
# 7                 Samukaa05/site-namorada  976312502       1
# 8                      gitbrent/PptxGenJS   52322425       1
# 9                          cap-js/cds-dbs  639043217       1
#
#                    created_at  \
# 0  2025-05-11 23:11:33.000000
# 1  2025-05-11 23:11:33.000000
# 2  2025-05-11 23:11:33.000000
# 3  2025-05-11 23:11:33.000000
# 4  2025-05-11 23:11:32.000000
# 5  2025-05-11 23:11:32.000000
# 6  2025-05-11 23:11:31.000000
# 7  2025-05-11 23:11:31.000000
# 8  2025-05-11 23:11:31.000000
# 9  2025-05-11 23:11:31.000000
#
#                                              payload
# 0                              {"action": "started"}
# 1  {"action": "opened", "number": 20, "pull_reque...
# 2  {"action": "closed", "number": 714, "pull_requ...
# 3                              {"action": "started"}
# 4                              {"action": "started"}
# 5  {"action": "opened", "number": 2905, "pull_req...
# 6                              {"action": "started"}
# 7  {"action": "opened", "number": 2, "pull_reques...
# 8                              {"action": "started"}
# 9  {"action": "opened", "number": 1187, "pull_req...

# %%
db_path = "data/silver/github_events.db"

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect(db_path)

query = "SELECT * FROM sqlite_master where type = 'table';"

df = pd.read_sql_query(query, conn)
conn.close()

# Print the table nicely
display(df)

conn.close()
# Out:
#     type    name tbl_name  rootpage  \
# 0  table  events   events         2
#
#                                                  sql
# 0  CREATE TABLE events (\n\tid VARCHAR NOT NULL, ...
